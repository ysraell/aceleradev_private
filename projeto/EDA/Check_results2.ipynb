# %% [markdown]
# # Template
#
# - Author: Israel Oliveira [\[e-mail\]](mailto:'Israel%20Oliveira%20'<prof.israel@gmail.com>)

# %%
# %load_ext watermark

# %%
import pandas as pd
from collections import Counter
from IPython.display import display

# %%
# Run this cell before close.
# %watermark -d --iversion -b -r -g -m -v
# Out:
# pandas 1.0.5
# 2020-07-26
#
# CPython 3.7.8
# IPython 7.16.1
#
# compiler   : GCC 8.3.0
# system     : Linux
# release    : 5.4.0-7634-generic
# machine    : x86_64
# processor  :
# CPU cores  : 8
# interpreter: 64bit
# Git hash   : 3c0017e07f2cd56b44646faab24086fa9abee984
# Git repo   : https://github.com/ysraell/aceleradev_private.git
# Git branch : master

# %%
import scipy
print(scipy.__version__)
# Out:
# 1.5.1

# %%
results_csv_name = 'Results_RC2.csv'
df_laoded = pd.read_csv(results_csv_name)
df_laoded = df_laoded.loc[:, ~df_laoded.columns.str.contains('^Unnamed')]
df_laoded['T_True'] = df_laoded[['P1_True','P2_True','P3_True']].sum(1)
df_laoded['T23_True'] = df_laoded[['P2_True','P3_True']].sum(1)
df_laoded['P23pp'] = df_laoded[['P2pp','P3pp']].mean(1)

# %%
len(df_laoded)
# Out:
# 892

# %%
df_laoded.sort_values(by='T23_True', ascending=False).head(5)
# Out:
#                pre_proc redux_func  n_components         dist            t  \
# 641  escalaropt_entropy       _NMF            62   BrayCurtis  1680.563012
# 302  escalaropt_entropy   _FastICA            40   BrayCurtis  1197.406659
# 587             Nothing   _FastICA            40  scy_cossine   971.599338
# 586             Nothing   _FastICA            40   np_cossine   974.062981
# 585             Nothing   _FastICA            40     Camberra   973.032357
#
#          P1pp  P1_True  P1_len      P2pp  P2_True  P2_len      P3pp  P3_True  \
# 641  0.000000        0     556  0.317460      180     567  0.285714       76
# 302  0.008993        5     556  0.320988      182     567  0.263158       70
# 587  0.008993        5     556  0.319224      181     567  0.263158       70
# 586  0.008993        5     556  0.319224      181     567  0.263158       70
# 585  0.008993        5     556  0.319224      181     567  0.263158       70
#
#      P3_len  T_True  T23_True     P23pp
# 641     266     256       256  0.301587
# 302     266     257       252  0.292073
# 587     266     256       251  0.291191
# 586     266     256       251  0.291191
# 585     266     256       251  0.291191

# %%
df_laoded.sort_values(by='T_True', ascending=False).head(5)
# Out:
#                pre_proc redux_func  n_components         dist            t  \
# 302  escalaropt_entropy   _FastICA            40   BrayCurtis  1197.406659
# 587             Nothing   _FastICA            40  scy_cossine   971.599338
# 585             Nothing   _FastICA            40     Camberra   973.032357
# 581             Nothing   _FastICA            38     Camberra   968.991314
# 582             Nothing   _FastICA            38   np_cossine   965.786916
#
#          P1pp  P1_True  P1_len      P2pp  P2_True  P2_len      P3pp  P3_True  \
# 302  0.008993        5     556  0.320988      182     567  0.263158       70
# 587  0.008993        5     556  0.319224      181     567  0.263158       70
# 585  0.008993        5     556  0.319224      181     567  0.263158       70
# 581  0.008993        5     556  0.313933      178     567  0.274436       73
# 582  0.008993        5     556  0.313933      178     567  0.274436       73
#
#      P3_len  T_True  T23_True     P23pp
# 302     266     257       252  0.292073
# 587     266     256       251  0.291191
# 585     266     256       251  0.291191
# 581     266     256       251  0.294185
# 582     266     256       251  0.294185

# %%
df_laoded.sort_values(by='P23pp', ascending=False).head(5)
# Out:
#                 pre_proc redux_func  n_components        dist            t  \
# 641   escalaropt_entropy       _NMF            62  BrayCurtis  1680.563012
# 647   escalaropt_entropy       _NMF            76  BrayCurtis  1842.714115
# 633   escalaropt_entropy       _NMF            42  BrayCurtis  1474.222248
# 545       escalaropt_std       _NMF            42  BrayCurtis  1409.839043
# 749  escalaropt_missings   _FastICA            62    Camberra   973.723928
#
#          P1pp  P1_True  P1_len      P2pp  P2_True  P2_len      P3pp  P3_True  \
# 641  0.000000        0     556  0.317460      180     567  0.285714       76
# 647  0.000000        0     556  0.305115      173     567  0.293233       78
# 633  0.008993        5     556  0.289242      164     567  0.308271       82
# 545  0.008993        5     556  0.289242      164     567  0.308271       82
# 749  0.003597        2     556  0.303351      172     567  0.293233       78
#
#      P3_len  T_True  T23_True     P23pp
# 641     266     256       256  0.301587
# 647     266     251       251  0.299174
# 633     266     251       246  0.298756
# 545     266     251       246  0.298756
# 749     266     252       250  0.298292

# %%
df_tmp = df_laoded.sort_values(by='T_True', ascending=False).head(10)
display(df_tmp)
Counter(df_tmp.dist).most_common()

# %%
df_tmp = df_laoded.sort_values(by='T_True', ascending=False).head(5)
display(df_tmp)
for col in df_tmp.columns:
    print(Counter(df_tmp[col]).most_common())

# %%
df_laoded.sort_values(by='T23_True', ascending=False).head(50)
# Out:
#                 pre_proc redux_func  n_components        dist            t  \
# 302   escalaropt_entropy   _FastICA            40  BrayCurtis  1197.406659
# 292       escalaropt_std   _FastICA            40  BrayCurtis  1200.390303
# 273              Nothing   _FastICA            40  BrayCurtis  1194.795704
# 285  escalaropt_missings   _FastICA            40  BrayCurtis  1196.051466
# 306   escalaropt_entropy   _FastICA            60  BrayCurtis  1302.336153
# 427       escalaropt_std   _FastICA            62  BrayCurtis  1311.468431
# 365              Nothing   _FastICA            62  BrayCurtis  1314.015275
# 544       escalaropt_std       _NMF            38  BrayCurtis  1393.466242
# 180       escalaropt_std       _NMF            35  BrayCurtis  1236.307439
# 356              Nothing   _FastICA            38  BrayCurtis  1183.708503
# 170  escalaropt_missings       _NMF            35  BrayCurtis  1240.702283
# 158              Nothing       _NMF            35  BrayCurtis  1238.244920
# 396  escalaropt_missings   _FastICA            62  BrayCurtis  1312.554755
# 195   escalaropt_entropy       _NMF            35  BrayCurtis  1239.667297
# 547       escalaropt_std       _NMF            46  BrayCurtis  1437.639349
# 545       escalaropt_std       _NMF            42  BrayCurtis  1409.839043
# 458   escalaropt_entropy   _FastICA            62  BrayCurtis  1310.122138
# 535  escalaropt_missings   _FastICA            38  BrayCurtis  1185.111130
# 387  escalaropt_missings   _FastICA            38  BrayCurtis  1185.111130
# 459   escalaropt_entropy   _FastICA            64  BrayCurtis  1322.590169
# 549       escalaropt_std       _NMF            52  BrayCurtis  1591.690840
# 449   escalaropt_entropy   _FastICA            38  BrayCurtis  1188.284544
# 397  escalaropt_missings   _FastICA            64  BrayCurtis  1319.112194
# 418       escalaropt_std   _FastICA            38  BrayCurtis  1186.137604
# 462   escalaropt_entropy   _FastICA            72  BrayCurtis  1386.335694
# 288  escalaropt_missings   _FastICA            60  BrayCurtis  1333.929912
# 386  escalaropt_missings   _FastICA            36  BrayCurtis  1173.904590
# 307   escalaropt_entropy   _FastICA            65  BrayCurtis  1327.636241
# 428       escalaropt_std   _FastICA            64  BrayCurtis  1323.437735
# 416       escalaropt_std   _FastICA            34  BrayCurtis  1166.165876
# 277              Nothing   _FastICA            60  BrayCurtis  1301.365141
# 295       escalaropt_std   _FastICA            60  BrayCurtis  1302.172814
# 550       escalaropt_std       _NMF            54  BrayCurtis  1630.619186
# 429       escalaropt_std   _FastICA            66  BrayCurtis  1333.631558
# 398  escalaropt_missings   _FastICA            66  BrayCurtis  1332.898193
# 366              Nothing   _FastICA            64  BrayCurtis  1323.247605
# 543       escalaropt_std       _NMF            36  BrayCurtis  1365.987451
# 553       escalaropt_std       _NMF            62  BrayCurtis  1674.836319
# 546       escalaropt_std       _NMF            44  BrayCurtis  1448.520815
# 451   escalaropt_entropy   _FastICA            44  BrayCurtis  1215.214474
# 296       escalaropt_std   _FastICA            65  BrayCurtis  1328.755229
# 450   escalaropt_entropy   _FastICA            42  BrayCurtis  1209.835044
# 357              Nothing   _FastICA            42  BrayCurtis  1203.375484
# 289  escalaropt_missings   _FastICA            65  BrayCurtis  1328.869874
# 367              Nothing   _FastICA            66  BrayCurtis  1331.937890
# 548       escalaropt_std       _NMF            48  BrayCurtis  1444.720407
# 238       escalaropt_std       _NMF            80  BrayCurtis  1930.203220
# 291       escalaropt_std   _FastICA            35  BrayCurtis  1177.460452
# 460   escalaropt_entropy   _FastICA            66  BrayCurtis  1329.283115
# 559       escalaropt_std       _NMF            76  BrayCurtis  1833.928915
#
#          P1pp  P1_True  P1_len      P2pp  P2_True  P2_len      P3pp  P3_True  \
# 302  0.008993        5     556  0.320988      182     567  0.263158       70
# 292  0.008993        5     556  0.320988      182     567  0.259398       69
# 273  0.008993        5     556  0.313933      178     567  0.266917       71
# 285  0.008993        5     556  0.313933      178     567  0.266917       71
# 306  0.000000        0     556  0.301587      171     567  0.293233       78
# 427  0.001799        1     556  0.299824      170     567  0.293233       78
# 365  0.003597        2     556  0.301587      171     567  0.289474       77
# 544  0.008993        5     556  0.301587      171     567  0.289474       77
# 180  0.007194        4     556  0.303351      172     567  0.281955       75
# 356  0.008993        5     556  0.305115      173     567  0.278195       74
# 170  0.007194        4     556  0.303351      172     567  0.281955       75
# 158  0.007194        4     556  0.303351      172     567  0.281955       75
# 396  0.001799        1     556  0.298060      169     567  0.293233       78
# 195  0.007194        4     556  0.303351      172     567  0.281955       75
# 547  0.008993        5     556  0.312169      177     567  0.263158       70
# 545  0.008993        5     556  0.289242      164     567  0.308271       82
# 458  0.003597        2     556  0.296296      168     567  0.293233       78
# 535  0.008993        5     556  0.308642      175     567  0.266917       71
# 387  0.008993        5     556  0.308642      175     567  0.266917       71
# 459  0.003597        2     556  0.299824      170     567  0.285714       76
# 549  0.003597        2     556  0.315697      179     567  0.251880       67
# 449  0.008993        5     556  0.305115      173     567  0.270677       72
# 397  0.003597        2     556  0.294533      167     567  0.293233       78
