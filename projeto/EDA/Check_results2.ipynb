# %% [markdown]
# # Template
#
# - Author: Israel Oliveira [\[e-mail\]](mailto:'Israel%20Oliveira%20'<prof.israel@gmail.com>)

# %%
# %load_ext watermark

# %%
import pandas as pd
from collections import Counter
from IPython.display import display

# %%
# Run this cell before close.
# %watermark -d --iversion -b -r -g -m -v
# Out:
# pandas 1.0.5
# 2020-07-16
#
# CPython 3.7.7
# IPython 7.16.1
#
# compiler   : GCC 8.3.0
# system     : Linux
# release    : 5.4.0-7634-generic
# machine    : x86_64
# processor  :
# CPU cores  : 8
# interpreter: 64bit
# Git hash   : 30ba73593d8a9aa656214e7030f2e3f09c6a4806
# Git repo   : https://github.com/ysraell/aceleradev_private.git
# Git branch : master

# %%
import scipy
print(scipy.__version__)
# Out:
# 1.5.0

# %%
results_csv_name = 'Results_RC2.csv'
df_laoded = pd.read_csv(results_csv_name)
df_laoded = df_laoded.loc[:, ~df_laoded.columns.str.contains('^Unnamed')]
df_laoded['T_True'] = df_laoded[['P1_True','P2_True','P3_True']].sum(1)
df_laoded['T23_True'] = df_laoded[['P2_True','P3_True']].sum(1)

# %%
len(df_laoded)
# Out:
# 315

# %%
df_laoded.sort_values(by='T23_True', ascending=False).head(5)
# Out:
#                 pre_proc redux_func  n_components        dist            t  \
# 304   escalaropt_entropy   _FastICA            40  BrayCurtis  1197.406659
# 294       escalaropt_std   _FastICA            40  BrayCurtis  1200.390303
# 287  escalaropt_missings   _FastICA            40  BrayCurtis  1196.051466
# 275              Nothing   _FastICA            40  BrayCurtis  1194.795704
# 308   escalaropt_entropy   _FastICA            60  BrayCurtis  1302.336153
#
#          P1pp  P1_True  P1_len      P2pp  P2_True  P2_len      P3pp  P3_True  \
# 304  0.008993        5     556  0.320988      182     567  0.263158       70
# 294  0.008993        5     556  0.320988      182     567  0.259398       69
# 287  0.008993        5     556  0.313933      178     567  0.266917       71
# 275  0.008993        5     556  0.313933      178     567  0.266917       71
# 308  0.000000        0     556  0.301587      171     567  0.293233       78
#
#      P3_len  T_True  T23_True
# 304     266     257       252
# 294     266     256       251
# 287     266     254       249
# 275     266     254       249
# 308     266     249       249

# %%
df_laoded.sort_values(by='T_True', ascending=False).head(20)
# Out:
#                 pre_proc redux_func  n_components        dist            t  \
# 304   escalaropt_entropy   _FastICA            40  BrayCurtis  1197.406659
# 294       escalaropt_std   _FastICA            40  BrayCurtis  1200.390303
# 275              Nothing   _FastICA            40  BrayCurtis  1194.795704
# 287  escalaropt_missings   _FastICA            40  BrayCurtis  1196.051466
# 180       escalaropt_std       _NMF            35  BrayCurtis  1236.307439
# 195   escalaropt_entropy       _NMF            35  BrayCurtis  1239.667297
# 158              Nothing       _NMF            35  BrayCurtis  1238.244920
# 170  escalaropt_missings       _NMF            35  BrayCurtis  1240.702283
# 308   escalaropt_entropy   _FastICA            60  BrayCurtis  1302.336153
# 309   escalaropt_entropy   _FastICA            65  BrayCurtis  1327.636241
# 279              Nothing   _FastICA            60  BrayCurtis  1301.365141
# 290  escalaropt_missings   _FastICA            60  BrayCurtis  1333.929912
# 213  escalaropt_missings   _FastICA            50  BrayCurtis  1284.093942
# 303   escalaropt_entropy   _FastICA            35  BrayCurtis  1177.438845
# 297       escalaropt_std   _FastICA            60  BrayCurtis  1302.172814
# 240       escalaropt_std       _NMF            80  BrayCurtis  1930.203220
# 293       escalaropt_std   _FastICA            35  BrayCurtis  1177.460452
# 298       escalaropt_std   _FastICA            65  BrayCurtis  1328.755229
# 291  escalaropt_missings   _FastICA            65  BrayCurtis  1328.869874
# 306   escalaropt_entropy   _FastICA            50  BrayCurtis  1249.082738
#
#          P1pp  P1_True  P1_len      P2pp  P2_True  P2_len      P3pp  P3_True  \
# 304  0.008993        5     556  0.320988      182     567  0.263158       70
# 294  0.008993        5     556  0.320988      182     567  0.259398       69
# 275  0.008993        5     556  0.313933      178     567  0.266917       71
# 287  0.008993        5     556  0.313933      178     567  0.266917       71
# 180  0.007194        4     556  0.303351      172     567  0.281955       75
# 195  0.007194        4     556  0.303351      172     567  0.281955       75
# 158  0.007194        4     556  0.303351      172     567  0.281955       75
# 170  0.007194        4     556  0.303351      172     567  0.281955       75
# 308  0.000000        0     556  0.301587      171     567  0.293233       78
# 309  0.003597        2     556  0.289242      164     567  0.289474       77
# 279  0.001799        1     556  0.292769      166     567  0.281955       75
# 290  0.000000        0     556  0.291005      165     567  0.289474       77
# 213  0.010791        6     556  0.273369      155     567  0.304511       81
# 303  0.008993        5     556  0.298060      169     567  0.251880       67
# 297  0.000000        0     556  0.289242      164     567  0.289474       77
# 240  0.003597        2     556  0.285714      162     567  0.285714       76
# 293  0.007194        4     556  0.294533      167     567  0.259398       69
# 298  0.001799        1     556  0.285714      162     567  0.289474       77
# 291  0.001799        1     556  0.283951      161     567  0.289474       77
# 306  0.008993        5     556  0.268078      152     567  0.300752       80
#
#      P3_len  T_True  T23_True
# 304     266     257       252
# 294     266     256       251
# 275     266     254       249
# 287     266     254       249
# 180     266     251       247
# 195     266     251       247
# 158     266     251       247
# 170     266     251       247
# 308     266     249       249
# 309     266     243       241
# 279     266     242       241
# 290     266     242       242
# 213     266     242       236
# 303     266     241       236
# 297     266     241       241
# 240     266     240       238
# 293     266     240       236
# 298     266     240       239
# 291     266     239       238
# 306     266     237       232

# %%
df_tmp = df_laoded.sort_values(by='T_True', ascending=False).head(10)
display(df_tmp)
Counter(df_tmp.dist).most_common()
# Out:
#                pre_proc redux_func  n_components         dist            t  \
# 29  escalaropt_missings       _NMF            50   np_cossine   961.240483
# 28  escalaropt_missings       _NMF            50   BrayCurtis   963.997076
# 27  escalaropt_missings       _NMF            50     Camberra   968.322599
# 26  escalaropt_missings       _NMF            50  scy_cossine   974.160070
# 25  escalaropt_missings       _NMF            50    Manhattan  1216.803251
# 43  escalaropt_missings       _NMF           120   BrayCurtis   962.815052
# 44  escalaropt_missings       _NMF           120   np_cossine   960.882513
# 42  escalaropt_missings       _NMF           120     Camberra   963.836225
# 41  escalaropt_missings       _NMF           120  scy_cossine   979.789134
# 40  escalaropt_missings       _NMF           120    Manhattan  1485.383268
#
#         P1pp  P1_True  P1_len      P2pp  P2_True  P2_len      P3pp  P3_True  \
# 29  0.003597        2     556  0.280423      159     567  0.266917       71
# 28  0.003597        2     556  0.280423      159     567  0.266917       71
# 27  0.003597        2     556  0.280423      159     567  0.266917       71
# 26  0.003597        2     556  0.280423      159     567  0.266917       71
# 25  0.003597        2     556  0.280423      159     567  0.266917       71
# 43  0.007194        4     556  0.252205      143     567  0.259398       69
# 44  0.007194        4     556  0.252205      143     567  0.259398       69
# 42  0.007194        4     556  0.252205      143     567  0.259398       69
# 41  0.007194        4     556  0.252205      143     567  0.259398       69
# 40  0.007194        4     556  0.252205      143     567  0.259398       69
#
#     P3_len  T_True
# 29     266     232
# 28     266     232
# 27     266     232
# 26     266     232
# 25     266     232
# 43     266     216
# 44     266     216
# 42     266     216
# 41     266     216
# 40     266     216
# [('np_cossine', 2),
#  ('BrayCurtis', 2),
#  ('Camberra', 2),
#  ('scy_cossine', 2),
#  ('Manhattan', 2)]

# %%
df_tmp = df_laoded.sort_values(by='T_True', ascending=False).head(5)
display(df_tmp)
for col in df_tmp.columns:
    print(Counter(df_tmp[col]).most_common())
# Out:
#                pre_proc redux_func  n_components         dist            t  \
# 26  escalaropt_missings       _NMF            50  scy_cossine   974.160070
# 27  escalaropt_missings       _NMF            50     Camberra   968.322599
# 28  escalaropt_missings       _NMF            50   BrayCurtis   963.997076
# 29  escalaropt_missings       _NMF            50   np_cossine   961.240483
# 25  escalaropt_missings       _NMF            50    Manhattan  1216.803251
#
#         P1pp  P1_True  P1_len      P2pp  P2_True  P2_len      P3pp  P3_True  \
# 26  0.003597        2     556  0.280423      159     567  0.266917       71
# 27  0.003597        2     556  0.280423      159     567  0.266917       71
# 28  0.003597        2     556  0.280423      159     567  0.266917       71
# 29  0.003597        2     556  0.280423      159     567  0.266917       71
# 25  0.003597        2     556  0.280423      159     567  0.266917       71
#
#     P3_len  T_True
# 26     266     232
# 27     266     232
# 28     266     232
# 29     266     232
# 25     266     232
# [('escalaropt_missings', 5)]
# [('_NMF', 5)]
# [(50, 5)]
# [('scy_cossine', 1), ('Camberra', 1), ('BrayCurtis', 1), ('np_cossine', 1), ('Manhattan', 1)]
# [(974.1600704193116, 1), (968.322598695755, 1), (963.9970757961273, 1), (961.2404828071594, 1), (1216.8032507896426, 1)]
# [(0.0035971223021582736, 5)]
# [(2, 5)]
# [(556, 5)]
# [(0.2804232804232804, 5)]
# [(159, 5)]
# [(567, 5)]
# [(0.2669172932330827, 5)]
# [(71, 5)]
# [(266, 5)]
# [(232, 5)]

# %%
df_tmp = df_laoded.sort_values(by='T_True', ascending=False).head(5)
df_tmp.sort_values(by='t')
# Out:
#                pre_proc redux_func  n_components         dist            t  \
# 29  escalaropt_missings       _NMF            50   np_cossine   961.240483
# 28  escalaropt_missings       _NMF            50   BrayCurtis   963.997076
# 27  escalaropt_missings       _NMF            50     Camberra   968.322599
# 26  escalaropt_missings       _NMF            50  scy_cossine   974.160070
# 25  escalaropt_missings       _NMF            50    Manhattan  1216.803251
#
#         P1pp  P1_True  P1_len      P2pp  P2_True  P2_len      P3pp  P3_True  \
# 29  0.003597        2     556  0.280423      159     567  0.266917       71
# 28  0.003597        2     556  0.280423      159     567  0.266917       71
# 27  0.003597        2     556  0.280423      159     567  0.266917       71
# 26  0.003597        2     556  0.280423      159     567  0.266917       71
# 25  0.003597        2     556  0.280423      159     567  0.266917       71
#
#     P3_len  T_True
# 29     266     232
# 28     266     232
# 27     266     232
# 26     266     232
# 25     266     232

# %%
df_laoded.groupby('dist').t.describe()
# Out:
#              count         mean         std          min          25%  \
# dist
# BrayCurtis    29.0  1006.630018   37.164878   960.419138   975.376649
# Camberra      29.0  1007.258203   39.885375   963.836225   977.759548
# Manhattan     29.0  1344.321516  228.468452  1040.668518  1134.766703
# np_cossine    29.0  1021.164514   61.060570   960.882513   972.440513
# scy_cossine   29.0  1033.832477   48.278344   966.116632   989.803458
#
#                      50%          75%          max
# dist
# BrayCurtis   1000.958881  1023.607082  1106.137883
# Camberra     1003.597332  1017.899064  1116.061538
# Manhattan    1349.305278  1494.763313  1774.575253
# np_cossine   1008.210139  1063.418866  1209.654883
# scy_cossine  1027.669024  1071.733254  1121.463677

# %%
list(df_laoded.sort_values(by='T_True', ascending=False).pre_proc)
# Out:
# ['Nothing',
#  'Nothing',
#  'Nothing',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'Nothing',
#  'Nothing',
#  'Nothing',
#  'Nothing',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'Nothing',
#  'Nothing',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'Nothing',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'Nothing',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'Nothing',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'Nothing',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'Nothing',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'escalaropt_missings',
#  'Nothing',
#  'escalaropt_missings']

# %%
df_laoded.query('redux_func == "_FactorAnalysis"').sort_values(by='T_True', ascending=False)
# Out:
#                 pre_proc       redux_func  n_components         dist  \
# 140  escalaropt_missings  _FactorAnalysis            30    Manhattan
# 144  escalaropt_missings  _FactorAnalysis            30   np_cossine
# 143  escalaropt_missings  _FactorAnalysis            30   BrayCurtis
# 142  escalaropt_missings  _FactorAnalysis            30     Camberra
# 141  escalaropt_missings  _FactorAnalysis            30  scy_cossine
# 139  escalaropt_missings  _FactorAnalysis            20   np_cossine
# 135  escalaropt_missings  _FactorAnalysis            20    Manhattan
# 136  escalaropt_missings  _FactorAnalysis            20  scy_cossine
# 137  escalaropt_missings  _FactorAnalysis            20     Camberra
# 138  escalaropt_missings  _FactorAnalysis            20   BrayCurtis
# 130  escalaropt_missings  _FactorAnalysis            10    Manhattan
# 131  escalaropt_missings  _FactorAnalysis            10  scy_cossine
# 134  escalaropt_missings  _FactorAnalysis            10   np_cossine
# 133  escalaropt_missings  _FactorAnalysis            10   BrayCurtis
# 132  escalaropt_missings  _FactorAnalysis            10     Camberra
# 145  escalaropt_missings  _FactorAnalysis            50   BrayCurtis
# 147  escalaropt_missings  _FactorAnalysis           100   BrayCurtis
# 146  escalaropt_missings  _FactorAnalysis            80   BrayCurtis
#
#                t      P1pp  P1_True  P1_len      P2pp  P2_True  P2_len  \
# 140  1197.355208  0.000000        0     556  0.231041      131     567
# 144  1033.866539  0.000000        0     556  0.231041      131     567
# 143  1055.668272  0.000000        0     556  0.231041      131     567
# 142  1026.953371  0.000000        0     556  0.231041      131     567
# 141  1086.985485  0.000000        0     556  0.231041      131     567
# 139  1209.654883  0.000000        0     556  0.234568      133     567
# 135  1123.534009  0.000000        0     556  0.234568      133     567
# 136  1090.567279  0.000000        0     556  0.234568      133     567
# 137   995.764658  0.000000        0     556  0.234568      133     567
# 138  1017.780995  0.000000        0     556  0.234568      133     567
# 130  1112.226563  0.003597        2     556  0.208113      118     567
# 131  1077.194933  0.003597        2     556  0.208113      118     567
# 134  1072.352525  0.003597        2     556  0.208113      118     567
# 133  1052.933405  0.003597        2     556  0.208113      118     567
# 132  1092.970923  0.003597        2     556  0.208113      118     567
# 145  1427.993742  0.007194        4     556  0.195767      111     567
# 147  1889.666252  0.000000        0     556  0.179894      102     567
# 146  1634.252285  0.003597        2     556  0.155203       88     567
#
#          P3pp  P3_True  P3_len  T_True
# 140  0.278195       74     266     205
# 144  0.278195       74     266     205
# 143  0.278195       74     266     205
# 142  0.278195       74     266     205
# 141  0.278195       74     266     205
# 139  0.263158       70     266     203
# 135  0.263158       70     266     203
# 136  0.263158       70     266     203
# 137  0.263158       70     266     203
# 138  0.263158       70     266     203
# 130  0.266917       71     266     191
# 131  0.266917       71     266     191
# 134  0.266917       71     266     191
# 133  0.266917       71     266     191
# 132  0.266917       71     266     191
# 145  0.270677       72     266     187
# 147  0.278195       74     266     176
# 146  0.251880       67     266     157
